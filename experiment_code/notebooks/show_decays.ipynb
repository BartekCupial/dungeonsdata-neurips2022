# %%
import matplotlib.pylab as plt



for decay in [0.9999, 0.99996, 0.99998]:
    data = []
    start_val = 0.5
    for i in range(240000):
        start_val *= decay
        data.append(start_val)

    plt.plot(data, label=f"{decay}")
plt.legend()
