# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load data from CSV
df = pd.read_csv("eval.csv")

# %%
# Create a histogram for sokobanfillpit_score
plt.hist(df['sokobanfillpit_score'], edgecolor='black', density=True)
plt.title('Sokoban Fillpit Score Distribution')
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.show()
